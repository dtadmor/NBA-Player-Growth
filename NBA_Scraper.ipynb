# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import regex as re
import time

# %% [markdown]
# # Basketball Reference data

# %%
df = pd.read_csv('./Seasons_Stats.csv', index_col='Unnamed: 0')

# %%
df.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM',
#        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
for column in df.columns:
    if len(df[column].value_counts()) == 0:
        print(column)
        df.drop(column, axis=1, inplace=True)
# Out:
# blanl
# blank2

# %% [markdown]
# # Scraping Class

# %%
class data(object):
    
    n=5
    url = ''
    headers = ''
    url_location = 'after'
    df = pd.DataFrame()
    else:
        import pandas as pd
        df = pd.DataFrame()
    
    def __init__(self):
        self.url = url
        self.headers = headers
        import_libs()
        print('Created a new scraper')
        return
    
    def scrape(self):
        result = requests.get(self.url, headers=self.headers)
        columns = result.json()['resultSets'][0]['headers'] # Need something for what to do with json
        return
        
    def change_url(self, url=url, change='', custom=False):
        if not custom:
            url = url + '?' + change
        else:
            url = custom(url)
        return url
    
    def repeated_scrape(self, n=n):
        for i in range(n):
            url = change_url(i)
            scrape(url)
        return
    
    def save_data(self):
        return
    
    def load_data(self):
        return
    
    def import_libs(self):
        try:
            pd
        else:
            import pandas as pd
        try:
            re
        else:
            import regex as re
        try:
            requests
        else:
            import requests
        try:
            time
        else:
            import time
            
        
           url = re.subf(r'Season=[-\d]+', 'Season={}'.format(season), url)
        result = requests.get(url, headers=headers)
        columns = result.json()['resultSets'][0]['headers'] # Need something for what to do with json
        df = pd.concat([df, pd.DataFrame(result.json()['resultSets'][0]['rowSet'], columns=columns)], axis=0)
        time.sleep(5)

# %% [markdown]
# # First Scrape

# %%
url = 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Possessions&Season=2016-17&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='

# %%
headers = { 'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36', 'Origin':'http://stats.nba.com', 'Referer':'http://stats.nba.com/game/' }

# %%
result = requests.get(url, headers=headers)

# %%
columns = result.json()['resultSets'][0]['headers']
pd.DataFrame(result.json()['resultSets'][0]['rowSet'], columns=columns)
# Out:
#      PLAYER_ID          PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  GP   W   L  \
# 0      1627773           AJ Hammons  1610612742               DAL  22   4  18
# 1       201166         Aaron Brooks  1610612754               IND  64  36  28
# 2       203932         Aaron Gordon  1610612753               ORL  80  29  51
# 3      1626151       Aaron Harrison  1610612766               CHA   5   2   3
# 4       203940        Adreian Payne  1610612750               MIN  18   5  13
# 5       201143           Al Horford  1610612738               BOS  68  46  22
# 6         2744         Al Jefferson  1610612754               IND  65  33  32
# 7       202329      Al-Farouq Aminu  1610612757               POR  61  33  28
# 8       101187        Alan Anderson  1610612746               LAC  30  20  10
# 9      1626210        Alan Williams  1610612756               PHX  47  11  36
# 10      202692           Alec Burks  1610612762               UTA  42  26  16
#       MIN  POINTS  TOUCHES         ...           TIME_OF_POSS  \
# 0     7.4     2.2      7.4         ...                    0.2
# 1    13.6     4.8     27.9         ...                    2.6
# 2    28.7    12.7     38.7         ...                    1.6
# 3     3.3     0.2      5.4         ...                    0.3
# 4     7.5     3.5     16.0         ...                    0.5
# 5    32.3    14.0     67.0         ...                    2.1
# 6    14.2     8.2     24.7         ...                    0.9
# 7    29.1     8.7     41.1         ...                    1.3
# 8    10.3     2.9     10.2         ...                    0.4
# 9    15.1     7.4     22.3         ...                    0.5
# 10   15.5     6.7     23.0         ...                    1.3
# 11   15.5     6.0     18.6         ...                    0.5
# 12   20.4     8.0     28.8         ...                    0.7
# 13   26.1    10.7     53.7         ...                    1.2
# 14   15.0     5.3     24.5         ...                    0.5
# 15   28.5    10.7     31.2         ...                    0.8
# 16    6.9     0.8      7.3         ...                    0.2
# 17   20.1     6.5     30.4         ...                    0.8
# 18    6.6     1.3     13.6         ...                    0.4
# 19   29.7    13.6     38.3         ...                    1.2
# 20   26.3     7.6     41.2         ...                    1.9
# 21   30.1     6.6     33.1         ...                    0.8
# 22   21.6     2.9     36.0         ...                    1.0
# 23   20.5     5.9     44.8         ...                    4.0
# 24    9.0     2.6     13.5         ...                    0.4
# 25   37.2    23.6     51.3         ...                    2.9
# 26   11.0     4.9     19.5         ...                    0.4
# 27   14.5     3.9     17.5         ...                    0.7
# 28   36.1    28.0     73.9         ...                    2.3
# 29   14.6     5.5     12.8         ...                    0.4
# ..    ...     ...      ...         ...                    ...
# 456  12.3     5.0     26.6         ...                    2.2
# 457  16.3     6.2     32.2         ...                    1.0
# 458  30.0     8.1     38.3         ...                    1.0
# 459  17.7     8.2     23.2         ...                    0.7
# 460  18.6     6.2     21.4         ...                    0.7
# 461  25.1     9.9     60.8         ...                    5.1
# 462  11.1     4.3     24.8         ...                    1.8
# 463  29.8    13.7     56.8         ...                    3.2
# 464  18.7     7.4     44.5         ...                    3.6
# 465  10.3     3.5     15.7         ...                    0.4
# 466  19.7    10.3     44.1         ...                    3.4
# 467  27.3     8.3     39.6         ...                    0.9
# 468  12.9     3.5     25.7         ...                    2.0
# 469   8.1     1.9      9.3         ...                    0.3
# 470  33.2    15.9     46.3         ...                    2.4
# 471  24.7     8.0     34.5         ...                    1.3
# 472  12.3     3.2     27.7         ...                    2.6
# 473  24.2    10.5     27.4         ...                    0.8
# 474  16.9     5.1     17.7         ...                    0.7
# 475  11.9     2.7     18.1         ...                    0.4
# 476  34.1    13.4     50.3         ...                    2.1
# 477  28.5    13.7     45.8         ...                    2.7
# 478  18.9     8.1     27.4         ...                    0.9
# 479  14.5     5.3     14.4         ...                    0.4
# 480  18.4     8.2     38.6         ...                    1.0
# 481  30.9    15.7     48.4         ...                    2.0
# 482  26.0    10.0     56.9         ...                    5.0
# 483  37.2    18.9     57.9         ...                    3.0
# 484  24.5    14.1     45.5         ...                    1.6
# 485  18.1     6.1     30.3         ...                    0.8
#
#      AVG_SEC_PER_TOUCH  AVG_DRIB_PER_TOUCH  PTS_PER_TOUCH  ELBOW_TOUCHES  \
# 13            0.0            3.3                0.500               0.000
# 14            0.6            3.2                0.667               0.208
# 15            0.0            0.6                0.766               1.000
# 16            0.0            0.8                0.000               0.000
# 17            0.9            4.3                0.345               0.296
# 18            0.5            1.7                0.235               0.000
# 19            5.0           11.0                0.396               0.596
# 20            0.7            2.1                0.298               0.415
# 21            0.1            3.2                0.487               0.000
# 22            1.3            4.1                0.158               0.278
# 23            0.1            0.4                0.417               0.333
# 24            1.1            1.2                0.444               0.350
# 25            4.1            3.2                0.532               0.647
# 26            0.5            2.2                0.250               0.800
# 27            0.0            0.6                1.000               0.000
# 28            6.5            6.8                0.715               0.672
# 29            0.2            0.2                1.200               1.111
# ..            ...            ...                  ...                 ...
# 456           0.0            0.2                0.200               0.000
# 457           1.0            0.9                0.340               0.211
# 458           0.2            7.5                0.516               0.375
# 459           0.1            0.4                0.189               0.000
# 460           0.0            1.3                1.182               2.000
# 461           0.1            0.9                0.385               0.500
# 462           0.0            0.2                0.667               0.000
# 463           0.1            1.3                0.427               0.167
# 464           0.0            0.2                0.118               0.500
# 465           0.5            2.5                0.441               0.192
# 466           0.6            0.7                0.471               0.273
# 467           1.0            7.9                0.333               0.043
# 468           0.0            0.3                0.286               0.000
# 469           0.4            1.6                0.333               0.000
# 470           0.3            1.6                0.507               0.476
# 471           1.0            1.0                0.319               0.542
# 472           0.1            0.4                0.308               0.000
# 473           0.0            0.3                0.276               1.000
# 474           0.0            0.3                0.182               0.000
# 475           0.1            0.5                0.400               0.000
# 476           2.5            0.7                0.371               0.345
# 477           0.2            1.5                0.700               0.417
# 478           2.1            5.3                0.420               0.361
# 479           1.2            4.1                0.500               0.265
# 480           2.6            5.6                0.462               0.267
# 481           1.5            3.1                0.590               0.552
# 482           0.1            0.5                0.455               0.600
# 483           0.0            0.9                1.083               0.000
# 484           8.9            5.8                0.342               0.521
# 485           2.0            5.1                0.362               0.259
#
#      PTS_PER_PAINT_TOUCH
# 0                  0.640
# 1                  0.308
# 2                  1.142
# 3                  0.000
# 4                  0.619
# 5                  0.688
# 6                  1.071
# 7                  0.578
# 8                  0.500
# 9                  0.903
# 10                 0.531
# 11                 0.318
# 12                 0.834
# 13                 0.700
# 14                 0.847
# 15                 0.580
# 16                 0.400
# 17                 0.933
# 18                 0.333
# 19                 0.906
# 20                 0.703
# 21                 0.759
# 22                 0.545
# 23                 0.593
# 24                 0.809
# 25                 1.034
# 26                 1.000
# 27                 0.571
# 28                 1.057
# 29                 0.364
# ..                   ...
# 456                0.800
# 457                0.734
# 458                0.731
# 459                0.552
# 460                0.750
# 461                0.403
# 462                0.615
# 463                0.731
# 464                0.700
# 465                0.724
# 466                0.714
# 467                0.890
# 468                0.737
# 469                0.840
# 470                0.981
# 471                0.568
# 472                0.308
# 473                0.526
# 474                0.750
# 475                0.667
# 476                0.811
# 477                0.824
# 478                0.864
# 479                0.911
# 480                0.815
# 481                0.860
# 482                0.783
# 483                0.786
# 484                0.981
# 485                0.635
#
# [486 rows x 21 columns]

# %% [markdown]
# # Scraping Functions

# %%
def past_seasons(n_years, end_year=18):
    
    # Create a list of years
    end_year = end_year
    seasons = []
    for i in range(1, n_years + 1):
        start_year = 18 - i
        season = '20{}-{}'.format(start_year, end_year)
        seasons.append(season)
        end_year = start_year
    
    return seasons

# %%
def nba_scraper(url, headers, n_years):
    
    # Initiate variables for the for loop
    df = pd.DataFrame()
    season_list = past_seasons(n_years)
    i = 1
    
    for season in season_list:
        
        # Creating the new url for the this season, scraping data, and saving it
        url = re.subf(r'Season=[-\d]+', 'Season={}'.format(season), url)
        result = requests.get(url, headers=headers)
        columns = result.json()['resultSets'][0]['headers']
        df = pd.concat([df, pd.DataFrame(result.json()['resultSets'][0]['rowSet'], columns=columns)], axis=0)
        
        # Updating the user and getting ready to scrape again
        print('Completed Scrape {} of {}'.format(i, len(season_list)))
        i += 1
        time.sleep(5)
    
    return df

# %%
def multi_scraoer(url_dict, headers, n_years):

# %%
headers = { 'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36', 'Origin':'http://stats.nba.com', 'Referer':'http://stats.nba.com/game/' }

# %%
url_dict = {
    'general_advanced': 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_touches': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Possessions&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_drives': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Drives&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_defensive_impact': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Defense&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_passing': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Passing&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_shooting_efficiency': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Efficiency&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_speed_distance': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=SpeedDistance&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_rebounding': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Rebounding&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_catch_shoot': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=CatchShoot&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_pullup_shooting': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=PullUpShot&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_elbow_touches': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=ElbowTouch&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_post_ups': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=PostTouch&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_paint_touches': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=PaintTouch&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_offensive_rebounding': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Rebounding&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'tracking_defensive_rebounding': 'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=Rebounding&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight=',
    'hustle': 'https://stats.nba.com/stats/leaguehustlestatsplayer?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&Height=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&TeamID=0&VsConference=&VsDivision=&Weight='
}

# %% [markdown]
# # Scraping

# %%
advanced = nba_scraper(url_dict['general_advanced'], 5)
touches = nba_scraper(url_dict['tracking_touches'], 5)
drives = nba_scraper(url_dict['tracking_drives'], 5)
defensive_impact = nba_scraper(url_dict['tracking_defensive_impact'], 5)
passing = nba_scraper(url_dict['tracking_passing'], 5)
shooting_efficiency = nba_scraper(url_dict['tracking_shooting_efficiency'], 5)
speed_distance = nba_scraper(url_dict['tracking_speed_distance'], 5)
rebounding = nba_scraper(url_dict['tracking_rebounding'], 5)
catch_shoot = nba_scraper(url_dict['tracking_catch_shoot'], 5)
pullup_shooting = nba_scraper(url_dict['tracking_pullup_shooting'], 5)
elbow_touches = nba_scraper(url_dict['tracking_elbow_touches'], 5)
post_ups = nba_scraper(url_dict['tracking_post_ups'], 5)
paint_touches = nba_scraper(url_dict['tracking_paint_touches'], 5)
offensive_rebounding = nba_scraper(url_dict['tracking_offensive_rebounding'], 5)
defensive_rebounding = nba_scraper(url_dict['tracking_defensive_rebounding'], 5)
hustle = nba_scraper(url_dict['hustle'], 5)
# Out:
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5
# Completed Scrape 1 of 5
# Completed Scrape 2 of 5
# Completed Scrape 3 of 5
# Completed Scrape 4 of 5
# Completed Scrape 5 of 5

# %% [markdown]
# # Saving Data

# %%
advanced.to_csv('./data/advanced')
touches.to_csv('./data/touches')
drives.to_csv('./data/drives')
defensive_impact.to_csv('./data/defensive_impact')
passing.to_csv('./data/passing')
shooting_efficiency.to_csv('./data/shooting_efficiency')
speed_distance.to_csv('./data/speed_distance')
rebounding.to_csv('./data/rebounding')
catch_shoot.to_csv('./data/catch_shoot')
pullup_shooting.to_csv('./data/pullup_shooting')
elbow_touches.to_csv('./data/elbow_touches')
post_ups.to_csv('./data/post_ups')
paint_touches.to_csv('./data/paint_touches')
offensive_rebounding.to_csv('./data/offensive_rebounding')
defensive_rebounding.to_csv('./data/defensive_rebounding')
hustle.to_csv('./data/hustle')

# %%
df_advanced = nba_scraper(advanced_url, 1)
# Out:
# Completed Scrape 1 of 1

# %%
df_advanced.columns
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'OFF_RATING', 'DEF_RATING', 'NET_RATING',
#        'AST_PCT', 'AST_TO', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT', 'REB_PCT',
#        'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'USG_PCT', 'PACE', 'PIE', 'FGM',
#        'FGA', 'FGM_PG', 'FGA_PG', 'FG_PCT', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'OFF_RATING_RANK', 'DEF_RATING_RANK',
#        'NET_RATING_RANK', 'AST_PCT_RANK', 'AST_TO_RANK', 'AST_RATIO_RANK',
#        'OREB_PCT_RANK', 'DREB_PCT_RANK', 'REB_PCT_RANK', 'TM_TOV_PCT_RANK',
#        'EFG_PCT_RANK', 'TS_PCT_RANK', 'USG_PCT_RANK', 'PACE_RANK', 'PIE_RANK',
#        'FGM_RANK', 'FGA_RANK', 'FGM_PG_RANK', 'FGA_PG_RANK', 'FG_PCT_RANK',
#        'CFID', 'CFPARAMS'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'GP', 'W',
#        'L', 'MIN', 'POINTS', 'TOUCHES', 'FRONT_CT_TOUCHES', 'TIME_OF_POSS',
#        'AVG_SEC_PER_TOUCH', 'AVG_DRIB_PER_TOUCH', 'PTS_PER_TOUCH',
#        'ELBOW_TOUCHES', 'POST_TOUCHES', 'PAINT_TOUCHES', 'PTS_PER_ELBOW_TOUCH',
#        'PTS_PER_POST_TOUCH', 'PTS_PER_PAINT_TOUCH'],
#       dtype='object')

# %%
df.head()
# Out:
#    PLAYER_ID     PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  GP   W   L   MIN  \
# 0     201166    Aaron Brooks  1610612750               MIN  32  19  13   5.9
# 1     203932    Aaron Gordon  1610612753               ORL  58  19  39  32.9
# 2    1626151  Aaron Harrison  1610612742               DAL   9   2   7  25.9
# 3    1627846     Abdel Nader  1610612738               BOS  47  32  15  11.1
# 4     203940   Adreian Payne  1610612753               ORL   5   0   5   8.5
#
#    POINTS  TOUCHES         ...           TIME_OF_POSS  AVG_SEC_PER_TOUCH  \
# 0     2.3     12.6         ...                    1.1               5.25
# 1    17.6     59.9         ...                    2.4               2.44
# 2     6.7     29.2         ...                    1.1               2.35
# 3     3.1     13.3         ...                    0.5               2.32
# 4     4.2     12.4         ...                    0.4               1.77
#
#    AVG_DRIB_PER_TOUCH  PTS_PER_TOUCH  ELBOW_TOUCHES  POST_TOUCHES  \
# 0                5.14          0.186            0.0           0.0
# 1                1.65          0.294            1.8           2.3
# 2                1.63          0.228            1.0           0.0
# 3                1.46          0.233            0.1           0.1
# 4                0.68          0.339            1.0           0.6
#
#    PAINT_TOUCHES  PTS_PER_ELBOW_TOUCH  PTS_PER_POST_TOUCH  PTS_PER_PAINT_TOUCH
# 0            0.1                0.000               0.000                0.000
# 1            3.9                0.673               0.458                0.974
# 2            0.3                0.000               0.000                1.333
# 3            0.5                0.000               1.000                0.455
# 4            1.0                0.200               0.667                1.000
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Use AWS or data bricks
# #### Use SQL NoSQL SPARK Distributed
# Work remotely?
